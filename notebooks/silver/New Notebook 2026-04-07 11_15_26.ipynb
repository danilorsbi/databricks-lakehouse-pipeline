# %%
df = spark.sql("""
    select
    * 
    --distinct neighborhood
    from
    workspace.drs_bronze.estabelecimentos_saude_goias 
    --where establishment_type = 'HOSPITAL GERAL'
    order by 1 asc
   --limit 10          
""")
display(df)

# %%
df = spark.sql("""
    select 
    *
    from
    workspace.drs_gold.cobertura_saude_por_bairro
    --workspace.drs_silver.estabelecimentos_saude_go          
    --order by 1 asc
    limit 10
""")
display(df)

# %%
df = spark.sql("""
          select * from workspace.drs_silver.socio_demografico
           limit 10 
          """)
display(df) 


dff = spark.sql("""
          select count(*) from workspace.drs_silver.covid_19
           limit 10 
          """)
display(dff) 

dffdddd = spark.sql("""
          select
          * 
          --distinct neighborhood 
          from workspace.drs_silver.local_votacao
           where neighborhood = 'vereda'
           limit 10 
          """)
display(dffdddd)

# %%
df = sparlk.sql("""
          select * from workspace.drs_silver.socio_demografico
           limit 10 
          """)

# %%
df = spark.sql("""
    select distinct rating, app_name as reating,
    
    count(*)            
    FROM workspace.drs_silver.reviews_apps               
    group by 1,2
""")
display(df)

# %%
# %sql
SELECT COUNT(*) AS total_reviews
FROM workspace.drs_gold.re

# %%
# %sql
SELECT
app_name,
COUNT(*) AS total_reviews
FROM workspace.drs_silver.reviews_apps
group by 1 
ORDER BY 1 desc
