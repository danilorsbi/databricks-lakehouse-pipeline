-- %%
CREATE CATALOG IF NOT EXISTS bmg_saude_desafio
  COMMENT 'Catalog do desafio tecnico - dados de beneficiarios ANS';

USE CATALOG bmg_saude_desafio;

CREATE SCHEMA IF NOT EXISTS bronze COMMENT 'Camada Bronze - dados brutos, as-is';
CREATE SCHEMA IF NOT EXISTS silver COMMENT 'Camada Silver - dados tipados e limpos';
CREATE SCHEMA IF NOT EXISTS gold   COMMENT 'Camada Gold - dados curados para consumo analitico';



USE CATALOG bmg_saude_desafio;

CREATE EXTERNAL VOLUME IF NOT EXISTS bronze.landing_zone
  LOCATION 's3://bmg-ans-01/raw-files/'
  COMMENT 'Landing zone (external volume) para o CSV bruto da ANS - espelha s3://bmg-ans-01/raw-files/';


LIST '/Volumes/bmg_saude_desafio/bronze/landing_zone/';
